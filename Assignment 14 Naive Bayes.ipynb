# %% [markdown]
# # Exercise 1 Salary Data

# %%
import numpy as np
import pandas as pd

# %%
df_train=pd.read_csv('D:/Megha/Desktop/DS assignments/assignment 14 Naive bayes/SalaryData_Train.csv')
df_train
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
df_train.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
df_train.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
df_test=pd.read_csv('D:/Megha/Desktop/DS assignments/assignment 14 Naive bayes/SalaryData_Test.csv')
df_test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
df=pd.concat([df_train,df_test])
df
# Out:
#        age          workclass   education  educationno        maritalstatus  \
# 0       39          State-gov   Bachelors           13        Never-married
# 1       50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2       38            Private     HS-grad            9             Divorced
# 3       53            Private        11th            7   Married-civ-spouse
# 4       28            Private   Bachelors           13   Married-civ-spouse
# ...    ...                ...         ...          ...                  ...
# 15055   33            Private   Bachelors           13        Never-married
# 15056   39            Private   Bachelors           13             Divorced
# 15057   38            Private   Bachelors           13   Married-civ-spouse
# 15058   44            Private   Bachelors           13             Divorced
# 15059   35       Self-emp-inc   Bachelors           13   Married-civ-spouse
#
# ...

# %%
workclass=pd.DataFrame(df_train.workclass.value_counts())
workclass
# Out:
#                    workclass
#  Private               22285
#  Self-emp-not-inc       2499
#  Local-gov              2067
#  State-gov              1279
#  Self-emp-inc           1074
#  Federal-gov             943
#  Without-pay              14

# %%
education=df_train.education.value_counts()

# %%
ms=df_train.maritalstatus.value_counts()

# %%
edno=df_train.educationno.value_counts()

# %%
rel=df_train.relationship.value_counts()

# %%
race=df_train.race.value_counts()

# %%
sex=df_train.sex.value_counts()

# %%
occ=df_train.occupation.value_counts()

# %%
nat=df_train.native.value_counts()

# %%
sal=df_train.Salary.value_counts()

# %%
import matplotlib.pyplot as plt
df.workclass.value_counts().plot.bar()
plt.show()

# %%
df.education.value_counts().plot.bar(color='red')
plt.show()

# %%
df.educationno.value_counts().plot.bar(color='green')
plt.show()

# %%
df.maritalstatus.value_counts().plot.bar(color='yellow')
plt.show()

# %%
df.occupation.value_counts().plot.bar(color='silver')
plt.show()

# %%
df.relationship.value_counts().plot.bar(color='orange')
plt.show()

# %%
df.race.value_counts().plot.bar(color='violet')
plt.show()

# %%
df.sex.value_counts().plot.bar(color='purple')
plt.show()

# %%
df.Salary.value_counts().plot.bar(color='aqua')
plt.show()

# %%
df_test.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
df_train['workclass']=labelencoder.fit_transform(df_train['workclass'])
df_train['education']=labelencoder.fit_transform(df_train['education'])
df_train['maritalstatus']=labelencoder.fit_transform(df_train['maritalstatus'])
df_train['occupation']=labelencoder.fit_transform(df_train['occupation'])
df_train['relationship']=labelencoder.fit_transform(df_train['relationship'])
df_train['race']=labelencoder.fit_transform(df_train['race'])
df_train['sex']=labelencoder.fit_transform(df_train['sex'])
df_train['native']=labelencoder.fit_transform(df_train['native'])
df_train['Salary']=labelencoder.fit_transform(df_train['Salary'])

# %%
workclass1=pd.DataFrame(df_train.workclass.value_counts())
workclass1
# Out:
#    workclass
# 2      22285
# 4       2499
# 1       2067
# 5       1279
# 3       1074
# 0        943
# 6         14

# %%
pd.concat([workclass,workclass1],axis=1)
# Out:
#                    workclass  workclass
# 0                        NaN      943.0
# 1                        NaN     2067.0
# 2                        NaN    22285.0
# 3                        NaN     1074.0
# 4                        NaN     2499.0
# 5                        NaN     1279.0
# 6                        NaN       14.0
#  Federal-gov           943.0        NaN
#  Local-gov            2067.0        NaN
#  Private             22285.0        NaN
#  Self-emp-inc         1074.0        NaN
#  Self-emp-not-inc     2499.0        NaN
#  State-gov            1279.0        NaN
#  Without-pay            14.0        NaN

# %% [markdown]
# - 0 is for Federal gov
# - 1 is for local gov
# - 2 is for private
# - 3 is for self employed inc
# - 4 is for self employed not inc
# - 5 is for state gov
# - 6 is for without pay

# %%
ed=pd.DataFrame(df_train.education.value_counts())
pd.concat([education,ed],axis=1)
# Out:
#                education  education
# 0                    NaN      820.0
# 1                    NaN     1048.0
# 2                    NaN      377.0
# 3                    NaN      151.0
# 4                    NaN      288.0
# 5                    NaN      557.0
# 6                    NaN      455.0
# 7                    NaN     1008.0
# 8                    NaN     1307.0
# 9                    NaN     5044.0
# 10                   NaN      375.0
# 11                   NaN     9840.0
# 12                   NaN     1627.0
# 13                   NaN       45.0
# 14                   NaN      542.0
# 15                   NaN     6677.0
#  10th              820.0        NaN
#  11th             1048.0        NaN
#  12th              377.0        NaN
#  1st-4th           151.0        NaN
#  5th-6th           288.0        NaN
#  7th-8th           557.0        NaN
#  9th               455.0        NaN
#  Assoc-acdm       1008.0        NaN
#  Assoc-voc        1307.0        NaN
# ...

# %% [markdown]
# - 0 is 10th
# - 1 is 11th
# - 2 is 12th
# - 3 is 1st - 4ht
# - 4 is 5th to 6th
# - 5 is 7th- 8th
# - 6 is 9th
# - 7 is Assoc-acdm
# - 8 is Assos-voc
# - 9 is bachelors
# - 10 is doctorate
# - 11 is HS-grad
# - 12 is masters
# - 13 is pre-school
# - 14 is prof school
# - 15 is some college

# %%
ms1=pd.DataFrame(df_train.maritalstatus.value_counts())
pd.concat([ms,ms1])
# Out:
#                               0  maritalstatus
#  Married-civ-spouse     14065.0            NaN
#  Never-married           9725.0            NaN
#  Divorced                4214.0            NaN
#  Separated                939.0            NaN
#  Widowed                  827.0            NaN
#  Married-spouse-absent    370.0            NaN
#  Married-AF-spouse         21.0            NaN
# 2                           NaN        14065.0
# 4                           NaN         9725.0
# 0                           NaN         4214.0
# 5                           NaN          939.0
# 6                           NaN          827.0
# 3                           NaN          370.0
# 1                           NaN           21.0

# %% [markdown]
# - 0 is divorced
# - 1 is Married-AF-spouse
# - 2 is Married-civ-spouse
# - 3 is Married-spouse-absent
# - 4 is Never-married
# - 5 is Separated
# - 6 is Widowed

# %%
rs=pd.DataFrame(df_train.relationship.value_counts())
pd.concat([rs,rel])
# Out:
#                  relationship        0
# 0                     12463.0      NaN
# 1                      7726.0      NaN
# 3                      4466.0      NaN
# 4                      3212.0      NaN
# 5                      1406.0      NaN
# 2                       888.0      NaN
#  Husband                  NaN  12463.0
#  Not-in-family            NaN   7726.0
#  Own-child                NaN   4466.0
#  Unmarried                NaN   3212.0
#  Wife                     NaN   1406.0
#  Other-relative           NaN    888.0

# %% [markdown]
# - 0 is husband
# - 1 is not-in-family
# - 2 is other relative
# - 3 is own child
# - 4 is unmarried
# - 5 is wife

# %%
rc=pd.DataFrame(df_train.race.value_counts())
pd.concat([rc,race])
# Out:
#                         race        0
# 4                    25932.0      NaN
# 2                     2817.0      NaN
# 1                      895.0      NaN
# 0                      286.0      NaN
# 3                      231.0      NaN
#  White                   NaN  25932.0
#  Black                   NaN   2817.0
#  Asian-Pac-Islander      NaN    895.0
#  Amer-Indian-Eskimo      NaN    286.0
#  Other                   NaN    231.0

# %% [markdown]
# - 0 is Amer-Indian-Eskimo
# - 1 is Asian-Pac-Islander
# - 2 is black
# - 3 is other
# - 4 is white

# %%
s=pd.DataFrame(df_train.sex.value_counts())
pd.concat([s,sex])
# Out:
#              sex        0
# 1        20380.0      NaN
# 0         9781.0      NaN
#  Male        NaN  20380.0
#  Female      NaN   9781.0

# %% [markdown]
# - 0 is male
# - 1 is female

# %%
o=pd.DataFrame(df_train.occupation.value_counts())
pd.concat([o,occ])
# Out:
#                     occupation       0
# 9                       4038.0     NaN
# 2                       4030.0     NaN
# 3                       3992.0     NaN
# 0                       3721.0     NaN
# 11                      3584.0     NaN
# 7                       3212.0     NaN
# 6                       1965.0     NaN
# 13                      1572.0     NaN
# 5                       1350.0     NaN
# 4                        989.0     NaN
# 12                       912.0     NaN
# 10                       644.0     NaN
# 8                        143.0     NaN
# 1                          9.0     NaN
#  Prof-specialty            NaN  4038.0
#  Craft-repair              NaN  4030.0
#  Exec-managerial           NaN  3992.0
#  Adm-clerical              NaN  3721.0
#  Sales                     NaN  3584.0
#  Other-service             NaN  3212.0
#  Machine-op-inspct         NaN  1965.0
#  Transport-moving          NaN  1572.0
#  Handlers-cleaners         NaN  1350.0
# ...

# %% [markdown]
# - 0 is adm-clerical
# - 1 is armed forces
# - 2 is craft repair
# - 3 is Exec-managerial
# - 4 is Farming-fishing
# - 5 is Handlers-cleaners
# - 6 is Machine-op-inspct
# - 7 is Other-service
# - 8 is Priv-house-serv
# - 9 is Prof-specialty
# - 10 is Protective-serv
# - 11 is sales
# - 12 is Tech-support
# - 13 is Transport-moving

# %%
S=pd.DataFrame(df_train.Salary.value_counts())
pd.concat([S,sal])
# Out:
#          Salary        0
# 0       22653.0      NaN
# 1        7508.0      NaN
#  <=50K      NaN  22653.0
#  >50K       NaN   7508.0

# %% [markdown]
# - 0 is <==50k
# - 1 is >50k

# %%
x_train=df_train.iloc[:,0:13]

# %%
x_train
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# ...

# %% [markdown]
# for workclass
# 0 is
# 1 is
# 2 is
# 3 is
# 4 is self employed not inc
# 5 is stategov

# %%
y_train=df_train.iloc[:,13:14]
y_train
# Out:
#        Salary
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 30156       0
# 30157       1
# 30158       0
# 30159       0
# 30160       1
#
# [30161 rows x 1 columns]

# %%
x_train=x_train.values
y_train=y_train.values

# %%
df_test['workclass']=labelencoder.fit_transform(df_test['workclass'])
df_test['education']=labelencoder.fit_transform(df_test['education'])
df_test['maritalstatus']=labelencoder.fit_transform(df_test['maritalstatus'])
df_test['occupation']=labelencoder.fit_transform(df_test['occupation'])
df_test['relationship']=labelencoder.fit_transform(df_test['relationship'])
df_test['race']=labelencoder.fit_transform(df_test['race'])
df_test['sex']=labelencoder.fit_transform(df_test['sex'])
df_test['native']=labelencoder.fit_transform(df_test['native'])
df_test['Salary']=labelencoder.fit_transform(df_test['Salary'])

# %%
x_test=df_test.iloc[:,0:13]
y_test=df_test.iloc[:,13:14]

# %%
x_test=x_test.values
y_test=y_test.values

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# C:\Users\Megha\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# GaussianNB()

# %%
y_train_pred=gnb.predict(x_train)

# %%
y_train_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
from sklearn import metrics
metrics.accuracy_score(y_train,y_train_pred)
# Out:
# 0.7953317197705646

# %%
y_test_pred=gnb.predict(x_test)
y_test_pred
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
metrics.accuracy_score(y_test,y_test_pred)
# Out:
# 0.7946879150066402

# %%
from sklearn.naive_bayes import MultinomialNB
mnb=MultinomialNB()
mnb.fit(x_train,y_train)
# Out:
# C:\Users\Megha\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# MultinomialNB()

# %%
y_train_pred_mnb=mnb.predict(x_train)
y_train_pred_mnb
# Out:
# array([1, 0, 0, ..., 0, 0, 1])

# %%
metrics.accuracy_score(y_train,y_train_pred_mnb)
# Out:
# 0.7729186698053778

# %%
y_test_pred_mnb=mnb.predict(x_test)
y_test_pred_mnb
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
metrics.accuracy_score(y_test_pred_mnb,y_test)
# Out:
# 0.7749667994687915
